# %% [markdown]
# # ESCUELA POLITÉCNICA NACIONAL
#
# ## MÉTODOS NUMÉRICOS
#
# ### TAREA 2

# %% [markdown]
# David Alejandro Puga Novoa - GR1CC - 30/10/2024

# %% [markdown]
# 1. Calcule los errores absoluto y relativo en las aproximaciones de 𝑝 por 𝑝*.
#
# * $𝑝 = 𝜋, 𝑝∗ = 22/7$
#
#   $|p-p*| = |𝜋-22/7| = 1,2644 * 10^-3$
#
#   $\frac{|p-p*|}{|p|} = \frac{|𝜋-22/7|}{|𝜋|} = 4,024 * 10^-4$
#
# * $𝑝 = 𝜋, 𝑝∗ = 3,1416$
#
#   $|p-p*| = |𝜋-3,1416| = 7,346* 10^-6$
#
#   $\frac{|p-p*|}{|p|} = \frac{|𝜋-3,1416|}{|𝜋|} = 2,338 * 10^-6$
#
# * $𝑝 = e, 𝑝∗ = 2,718$
#
#   $|p-p*| = |e-2,718| = 2,818* 10^-4$
#
#   $\frac{|p-p*|}{|p|} = \frac{|e-2,718|}{|e|} = 1,036 * 10^-4$
#
# * $𝑝 = \sqrt{2}, 𝑝∗ = 1,414$
#
#   $|p-p*| = |\sqrt{2}-1,414| = 2,135* 10^-4$
#
#   $\frac{|p-p*|}{|p|} = \frac{|\sqrt{2}-1,414|}{|\sqrt{2}|} = 1,51 * 10^-4$

# %% [markdown]
# 2. Calcule los errores absoluto y relativo en las aproximaciones de 𝑝 por 𝑝∗
#
# * $𝑝 = e^10, 𝑝∗ = 22000$
#
#   $|p-p*| = |e^10 - 22000| = 26,465$
#
#   $\frac{|p-p*|}{|p|} = \frac{|e^10 - 22000|}{|e^10|} = 1,2 * 10^-3$
#
# * $𝑝 = 10^𝜋, 𝑝∗ = 1400$
#
#   $|p-p*| = |10^𝜋 - 1400| = 14,544$
#
#   $\frac{|p-p*|}{|p|} = \frac{|10^𝜋 - 1400|}{|10^𝜋|} = 0,0104$
#
# * $𝑝 = 8!, 𝑝∗ = 39900$
#
#   $|p-p*| = |8!-39900| = 420$
#
#   $\frac{|p-p*|}{|p|} = \frac{|8!-39900|}{|8!|} = 0,01$
#
# * $𝑝 = 9!, 𝑝∗ = \sqrt{18𝜋}(\frac{9}{e})^9$
#
#   $|p-p*| = |9! - \sqrt{18𝜋}\frac{9}{e}^9| = 3343,12$
#
#   $\frac{|p-p*|}{|p|} = \frac{|9! - \sqrt{18𝜋}\frac{9}{e}^9|}{|9!|} = 9,21 * 10^-3$

# %% [markdown]
# 3. Encuentre el intervalo más largo en el que se debe encontrar 𝑝∗ para aproximarse a 𝑝 con error relativo máximo de 10^−4 para cada valor de 𝑝.
#
# * $𝜋$
#
#  $\frac{|p-p*|}{|p|} = \frac{|𝜋-p*|}{|𝜋|} = 10^-4$
#
#  $\frac{𝜋-p*}{𝜋} = 10^-4$ y $\frac{𝜋-p*}{𝜋} = -10^-4$
#
#  $p* = 3,141278494$ ó $p* = 3,141906813$
#
#  $p * ∈ [3,141278494 ,3,141906813]$
#
# * $𝜋$
#
#  $\frac{|p-p*|}{|p|} = \frac{|𝜋-p*|}{|𝜋|} = 10^-4$
#
#  $\frac{𝜋-p*}{𝜋} = 10^-4$ y $\frac{𝜋-p*}{𝜋} = -10^-4$
#
#  $p* = 3,141278494$ ó $p* = 3,141906813$
#
#  $p * ∈ [3,141278494 ,3,141906813]$
#
# * $e$
#
#  $\frac{|p-p*|}{|p|} = \frac{|e-p*|}{|e|} = 10^-4$
#
#  $\frac{e-p*}{e} = 10^-4$ y $\frac{e-p*}{e} = -10^-4$
#
#  $p* = 2,71801$ ó $p* = 2,718553657$
#
#  $p * ∈ [2,71801 ,2,718553657]$
#
# * $\sqrt{2}$
#
#  $\frac{|p-p*|}{|p|} = \frac{|\sqrt{2}-p*|}{|\sqrt{2}|} = 10^-4$
#
#  $\frac{\sqrt{2}-p*}{\sqrt{2}} = 10^-4$ y $\frac{\sqrt{2}-p*}{\sqrt{2}} = -10^-4$
#
#  $p* = 1,414072141$ ó $p* = 1,414354984$
#
#  $p * ∈ [1,41407214 ,1,414354984]$
#
# * $\sqrt{7}$
#
#  $\frac{|p-p*|}{|p|} = \frac{|\sqrt{7}-p*|}{|\sqrt{7}|} = 10^-4$
#
#  $\frac{\sqrt{7}-p*}{\sqrt{7}} = 10^-4$ y $\frac{\sqrt{7}-p*}{\sqrt{7}} = -10^-4$
#
#  $p* = 1,91273989$ ó $p* = 1,913122476$
#
#  $p * ∈ [1,91273989 ,1,913122476]$

# %% [markdown]
# 4. Use la aritmética de redondeo de tres dígitos para realizar lo siguiente. Calcule los errores absoluto y relativo
# con el valor exacto determinado para por lo menos cinco dígitos.
#
# * $\frac{\frac{13}{14}-\frac{5}{7}}{2e-5,4}$
#
#   $p = 0,58606*10^1 ; p= 0,586*10^1$
#
#   $|p-p*|= 6 * 10^-4$ y $\frac{|p-p*|}{|p|} = 1,024 * 10^-4$
#
# * $-10𝜋+6e-\frac{3}{61}$
#
#   $p = -0,15155*10^2 ; p= -0,152*10^2$
#
#   $|p-p*|= 0x045$ y $\frac{|p-p*|}{|p|} = 2x9693 * 10^-4$
#
#
# * $\frac{2}{9} * \frac{9}{11}$
#
#   $p = 0,18182 ; p= 0,182$
#
#   $|p-p*|= 1,8*10^-4 $ y $\frac{|p-p*|}{|p|} = 9,899 * 10^-4$
#
#
# * $\frac{\sqrt{13}+\sqrt{11}}{\sqrt{13}-\sqrt{11}}$
#
#   $p = ,0,23958*10^2 ; p= 0,240*10^2$
#
#   $|p-p*|= 0,042$ y $\frac{|p-p*|}{|p|} = 1,753 * 10^-3$

# %% [markdown]
# 5. . Los primeros tres términos diferentes a cero de la serie de Maclaurin para la función arcotangente son:𝑥 − (1/3)𝑥^3 + (1/5)𝑥^5. Calcule los errores absoluto y relativo en las siguientes aproximaciones de 𝜋 mediante el polinomio en lugar del arcotangente.
#
# * $4[arctan \frac{1}{2} + arctan \frac{1}{3}]$
#
#   $|𝜋-p*| = 3,98* 10^-3$
#
#   $\frac{|𝜋-p*|}{|𝜋|} = 1,267 * 10^-3$
#
# * $16arctan \frac{1}{5} - 4 arctan \frac{1}{236}$
#
#   $|𝜋-p*| = 2,83* 10^-5$
#
#   $\frac{|𝜋-p*|}{|𝜋|} = 9,03 * 10^-6$

# %% [markdown]
# 6. Calcule los errores absoluto y relativo en la siguiente aproximación de e:
#
# * $Σ(5,n=0)\frac{1}{!n}$
#
#   $Σ(5,n=0)\frac{1}{!n} = 2,716666667 = p*$
#
#   $|e-p*| = 1,615* 10^-3$
#
#   $\frac{|e-p*|}{|e|} = 5,94 * 10^-4$
#
# * $Σ(10,n=0)\frac{1}{!n}$
#
#   $Σ(10,n=0)\frac{1}{!n} = 2,718281801 = p*$
#
#   $|e-p*| = 2,731* 10^-8$
#
#   $\frac{|e-p*|}{|e|} = 1,004 * 10^-8$

# %% [markdown]
# 7. Suponga que dos puntos (𝑥0, 𝑦0) y (𝑥1, 𝑦1) se encuentran en línea recta con 𝑦1 ≠ 𝑦0. Existen dos fórmulas para encontrar la intersección 𝑥 de la línea:
#
# $ x=\frac{x_0y_1-x_1y_0}{y1-y0}$ : $x=x_0 - \frac{(x_1-x_0)y0}{y_1 - y_0}$
#
# a. Use los datos (𝑥0, 𝑦0) = (1.31, 3.24) y (𝑥1, 𝑦1) = (1.93, 5. 76) y la aritmética de redondeo de tres dígitos para calcular la intersección con 𝑥 de ambas maneras.
#
# * Primer método
#
#   $x=\frac{x_0y_1-x_1y_0}{y1-y0} = 0,5128571429$
#
# * Segundo método
#
#   $x=x_0 - \frac{(x_1-x_0)y0}{y_1 - y_0} = 0,5128571429$
#
# ¿Cuál método es mejor y por qué?
#
# Realmento ambos métodos dan como resutado el mismo valor, por lo que se puede concluir que el error al momento de redondear a 3 dígitos es el mismo.
